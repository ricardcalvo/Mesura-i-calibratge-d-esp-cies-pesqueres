# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=a76fa842f971b5b5ebb1958d5df78914d19cf3afd9518b210f2a7ed23a96e08a
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My\ Drive/software/Unet_Pytorch/Data/
# Out:
# /gdrive/My Drive/software/Unet_Pytorch/Data

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Sep 23 09:53:14 2020

@author: vicenc
"""

######################################################################################################################################
# Parameters

base_dir = '/gdrive/My Drive/software/Unet_Pytorch/Data/'
dataname='sardines'
experiment = 'experiment_final'
carpeta_masks_train = 'sardina_train' 
carpeta_masks_val = 'sardina_val' 

#------- Image size parameters

# The images can be of any size or aspect ratio (width, height): We are going to pad them to make them square and to resize before extracting tiles


# Images are 512x512: patches size needs to be < 512x512 

patch_size_h = 576  #size of the tiles or patches to extract and save in the database, must be >= than training size
patch_size_v = 416  #size of the tiles or patches to extract and save in the database, must be >= than training size

rotation_angle_inc = 20 #degrees

resize_h= patch_size_h+1 #pad and resize input images to (resize x resize) pixels before extracting the tiles.
resize_v= patch_size_v+1

mirror_pad_size=0 # number of pixels to pad *after* resize to image with by mirroring 
step = 1 #distance to skip between patches, 1 indicates pixel wise extraction, patch_size would result in non-overlapping tiles

#-----Note---
#One should likely make sure that  (nrow+mirror_pad_size) mod patch_size == 0, where nrow is the number of rows after resizing
#so that no pixels are lost (any remainer is ignored)

#-------- Training / Validation / Test set parameters

test_set_size=0.1 # what percentage of the dataset should be used as a held out validation/testing set
classes=[0,1] #what classes we expect to have in the data,

# %%
######################################################################################################################################
import sklearn
#print(sklearn.__version__)
import tables
import os,sys
import glob
import PIL
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn import model_selection
import sklearn.feature_extraction.image
import sklearn.feature_extraction
import random

seed = random.randrange(sys.maxsize) #get a random seed so that we can reproducibly do the cross validation setup
random.seed(seed) # set the seed
print(f"random seed (note down for reproducibility): {seed}")
# Out:
# random seed (note down for reproducibility): 6540568271838006887

# %%
######################################################################################################################################

os.chdir(base_dir +'/'+dataname+'/'+experiment)

seed = random.randrange(sys.maxsize) #get a random seed so that we can reproducibly do the cross validation setup
random.seed(seed) # set the seed
#print(f"random seed (note down for reproducibility): {seed}")

img_dtype = tables.UInt8Atom()  # dtype in which the images will be saved, this indicates that images will be saved as unsigned int 8 bit, i.e., [0,255]
filenameAtom = tables.StringAtom(itemsize=255) #create an atom to store the filename of the image, just in case we need it later.

#editar aixo dividr el conjunt    15 per training i 5 per validació, una imatge no pot estar en els dos

files_train=glob.glob('../'+carpeta_masks_train+'/*mask.png') # create a list of the files, in this case we're only interested in files which have masks so we can use supervised learning
files_val=glob.glob('../'+carpeta_masks_val+'/*mask.png')
#Definim
train_img_num=list(range(len(files_train))) #llista de numeros del 0 fins len(files_train)
val_img_num=list(range(len(files_val)))
#create training and validation stages 
phases={}
random.shuffle(train_img_num) 
random.shuffle(val_img_num)
phases["train"] = np.array(train_img_num)
phases["val"] = np.array(val_img_num)
#phases["train"],phases["val"]=next(iter(model_selection.ShuffleSplit(n_splits=1,test_size=test_set_size).split(files)))

print(f"\tDataset: {dataname}")
print(f"\tExperiment: {experiment}")
print(f"\tImages size: {patch_size_h} x {patch_size_v}")
print(f"\tNumber of training images: {len(phases['train'])}")
print(f"\tNumber of validation images: {len(phases['val'])}")
print(f"\tTraining / Validation : {100*(1-test_set_size)} % / {100*(test_set_size)} %")


#specify that we'll be saving 2 different image types to the database, an image and its associated masked
imgtypes=["img","mask"]

storage={} # holder for future pytables

block_shape={} #block shape specifies what we'll be saving into the pytable array, here we assume that masks are 1d and images are 3d
block_shape["img"]= np.array((patch_size_v,patch_size_h,3))
block_shape["mask"]= np.array((patch_size_v,patch_size_h)) 

filters=tables.Filters(complevel=0, complib='zlib') #we can also specify filters, such as compression, to improve storage speed
# Out:
# 	Dataset: sardines
# 	Experiment: experiment_final
# 	Images size: 576 x 416
# 	Number of training images: 1692
# 	Number of validation images: 234
# 	Training / Validation : 90.0 % / 10.0 %

# %%
for phase in phases.keys(): #now for each of the phases (train and validation), we'll loop through the files
    print('')
    print(phase)
    print(f"Storing data in: ./{dataname}_{phase}.pytable")
    
    totals=np.zeros((2,len(classes))) # we counts of all the pixels belonging to (object instance or background) classes
                                        #in for in particular training, since we 
    totals[0,:]=classes               # can later use this information to create better weights for the loss.

    hdf5_file = tables.open_file(f"./{dataname}_{phase}.pytable", mode='w') #open the respective pytable
    storage["filename"] = hdf5_file.create_earray(hdf5_file.root, 'filename', filenameAtom, (0,)) #create the array for storage
    
    for imgtype in imgtypes: #for each of the image types, in this case mask and image, we need to create the associated array
        storage[imgtype]= hdf5_file.create_earray(hdf5_file.root, imgtype, img_dtype,  
                                                  shape=np.append([0],block_shape[imgtype]), 
                                                  chunkshape=np.append([1],block_shape[imgtype]),
                                                  filters=filters)
    
    for filei in phases[phase]: #now for each of the files
        print(filei)
        if phase== "train":
          fname=files_train[filei]
          carpeta_masks=carpeta_masks_train
        else:
          fname=files_val[filei]
          carpeta_masks=carpeta_masks_val
        print(fname)
        print('.', end='')
        for imgtype in imgtypes:
            if(imgtype=="img"): #if we're looking at an img, it must be 3 channel, but cv2 won't load it in the correct channel order, so we need to fix that
                io=cv2.cvtColor(cv2.imread("../"+carpeta_masks +"/"+os.path.basename(fname).replace("_mask.png",".jpg")),cv2.COLOR_BGR2RGB)
                height = io.shape[0]
                width =  io.shape[1]
                '''
                #Convert to square image                
                if height > width:
                    io = cv2.copyMakeBorder(io, 0, 0, 0, height-width, cv2.BORDER_CONSTANT,value=[0,0,0])
                elif height < width :
                    io = cv2.copyMakeBorder( io, 0, width-height, 0, 0, cv2.BORDER_CONSTANT,value=[0,0,0])
                '''
                #io = cv2.resize(io,(resize_h,resize_v), interpolation=PIL.Image.LANCZOS) #resize it as specified above
                #plt.imshow(io)

            else: #if its a mask image, then we only need a single channel 
                io=cv2.imread(fname)/255 #the image is loaded as {0,255}, but we'd like to store it as {0,1} since this represents the binary nature of the mask easier
                interp_method=PIL.Image.NEAREST #want to use nearest! otherwise resizing may cause non-existing classes to be produced via interpolation (e.g., ".25")
                height = io.shape[0]
                width =  io.shape[1]
                '''
                #Convert to square image                
                if height > width:
                    io = cv2.copyMakeBorder(io, 0, 0, 0, height-width, cv2.BORDER_CONSTANT,value=[0,0,0])
                elif height < width :
                    io = cv2.copyMakeBorder( io, 0, width-height, 0, 0, cv2.BORDER_CONSTANT,value=[0,0,0])
                '''
                #io = cv2.resize(io,(resize_h,resize_v), interpolation=interp_method) #resize it as specified above
                #plt.imshow(io)
                #plt.show()
                
                for i,key in enumerate(classes): #sum the number of pixels, this is done pre-resize, but proportions don't change which is really what we're after
                    totals[1,i]+=sum(sum(io[:,:,0]==key))

            
            #io = np.pad(io, [(mirror_pad_size, mirror_pad_size), (mirror_pad_size, mirror_pad_size), (0, 0)], mode="reflect")

            #convert input image into overlapping tiles, size is ntiler x ntilec x 1 x patch_size x patch_size x 3          
            #https://github.com/scikit-learn/scikit-learn/blob/a24c8b46/sklearn/feature_extraction/image.py#L241
            
            io_arr_out=sklearn.feature_extraction.image.extract_patches(io,(patch_size_v,patch_size_h,3),step)
            #resize it into a ntile x patch_size x patch_size x 3
            io_arr_out=io_arr_out.reshape(-1,patch_size_v,patch_size_h,3)
            
            '''
            plt.imshow(io)
            plt.show()
            plt.imshow(io_arr_out[2,:,:,:])
            plt.show()
            '''
            
            #save the 4D tensor to the table
            if (imgtype=="img"):
                storage[imgtype].append(io_arr_out)
            else:
                storage[imgtype].append(io_arr_out[:,:,:,0].squeeze()) #only need 1 channel for mask data

        storage["filename"].append([fname for x in range(io_arr_out.shape[0])]) #add the filename to the storage array
        
    #lastely, we should store the number of pixels
    npixels=hdf5_file.create_carray(hdf5_file.root, 'numpixels', tables.Atom.from_dtype(totals.dtype), totals.shape)
    npixels[:]=totals
    hdf5_file.close()
# Out:
# train
# Storing data in: ./sardines_train.pytable
# 75
# ../sardina_train/IMG_4366_r_160_mask.png
# .
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function extract_patches is deprecated; The function feature_extraction.image.extract_patches has been deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(msg, category=FutureWarning)
# 1112
# ../sardina_train/IMG_3423_r_60_mask.png
# .41
# ../sardina_train/IMG_3515_r_100_mask.png
# .395
# ../sardina_train/IMG_3460_r_160_mask.png
# .1002
# ../sardina_train/IMG_3417_r_20_mask.png
# .82
# ../sardina_train/IMG_4366_r_40_mask.png
# .1616
# ../sardina_train/IMG_3414_r_60_mask.png
# .941
# ../sardina_train/IMG_3453_r_260_mask.png
# .1160
# ../sardina_train/IMG_3425_r_300_mask.png
# .309
# ../sardina_train/IMG_4320_r_300_mask.png
# .810
# ../sardina_train/IMG_3446_r_160_mask.png
# .926
# ../sardina_train/IMG_3452_r_320_mask.png
# .704
# ../sardina_train/IMG_3437_r_200_mask.png
# .633
# ../sardina_train/IMG_3477_r_240_mask.png
# .1328
# ../sardina_train/IMG_3389_r_60_mask.png
# .1083
# ../sardina_train/IMG_3421_r_200_mask.png
# .497
# ../sardina_train/IMG_3466_r_40_mask.png
# .992
# ../sardina_train/IMG_3416_r_180_mask.png
# .429
# ../sardina_train/IMG_3462_r_120_mask.png
# .57
# ../sardina_train/IMG_3516_r_60_mask.png
# .32
# ../sardina_train/IMG_3514_r_280_mask.png
# .302
# ../sardina_train/IMG_4320_r_120_mask.png
# .1026
# ../sardina_train/IMG_3418_r_140_mask.png
# .411
# ../sardina_train/IMG_3461_r_120_mask.png
# ../sardina_train/IMG_3460_r_280_mask.png
# .961
# ../sardina_train/IMG_3454_r_300_mask.png
# .795
# ../sardina_train/IMG_3445_r_220_mask.png
# .913
# ../sardina_train/IMG_3452_r_60_mask.png
# .209
# ../sardina_train/IMG_4322_r_340_mask.png
# .431
# ../sardina_train/IMG_3462_r_160_mask.png
# .42
# ../sardina_train/IMG_3515_r_120_mask.png
# .205
# ../sardina_train/IMG_4322_r_220_mask.png
# .622
# ../sardina_train/IMG_3477_r_20_mask.png
# .1052
# ../sardina_train/IMG_3419_r_300_mask.png
# .947
# ../sardina_train/IMG_3454_r_20_mask.png
# .1185
# ../sardina_train/IMG_3427_r_80_mask.png
# .902
# ../sardina_train/IMG_3451_r_200_mask.png
# .769
# ../sardina_train/IMG_3444_r_60_mask.png
# .1187
# ../sardina_train/IMG_3427_r_120_mask.png
# .486
# ../sardina_train/IMG_3465_r_180_mask.png
# .968
# ../sardina_train/IMG_3455_r_80_mask.png
# .1031
# ../sardina_train/IMG_3418_r_240_mask.png
# .564
# ../sardina_train/IMG_3473_r_300_mask.png
# .1126
# ../sardina_train/IMG_3423_r_340_mask.png
# .1214
# ../sardina_train/IMG_3428_r_300_mask.png
# .200
# ../sardina_train/IMG_4323_r_280_mask.png
# .1244
# ../sardina_train/IMG_3430_r_180_mask.png
# .1136
# ../sardina_train/IMG_3424_r_180_mask.png
# .1471
# ../sardina_train/IMG_3398_r_40_mask.png
# .243
# ../sardina_train/IMG_4321_r_200_mask.png
# .1474
# ../sardina_train/IMG_3398_r_100_mask.png
# .225
# ../sardina_train/IMG_4322_r_40_mask.png
# .573
# ../sardina_train/IMG_3474_r_120_mask.png
# .542
# ../sardina_train/IMG_3472_r_220_mask.png
# .1307
# ../sardina_train/IMG_3434_r_0_mask.png
# .1080
# ../sardina_train/IMG_3421_r_140_mask.png
# .
# val
# Storing data in: ./sardines_val.pytable
# 197
# ../sardina_val/IMG_3520_r_340_mask.png
# .12
# ../sardina_val/IMG_3401_r_240_mask.png
# .18
# ../sardina_val/IMG_3401_r_340_mask.png
# .143
# ../sardina_val/IMG_3485_r_340_mask.png
# .31
# ../sardina_val/IMG_3402_r_260_mask.png
# .89
# ../sardina_val/IMG_3482_r_340_mask.png
# .123
# ../sardina_val/IMG_3484_r_320_mask.png
# .57
# ../sardina_val/IMG_3480_r_80_mask.png
# .78
# ../sardina_val/IMG_3482_r_120_mask.png
# .166
# ../sardina_val/IMG_3487_r_80_mask.png
# .215
# ../sardina_val/IMG_4350_r_320_mask.png
# .53
# ../sardina_val/IMG_3410_r_340_mask.png
# .15
# ../sardina_val/IMG_3401_r_300_mask.png
# .19
# ../sardina_val/IMG_3402_r_20_mask.png
# .80
# ../sardina_val/IMG_3482_r_160_mask.png
# .91
# ../sardina_val/IMG_3483_r_20_mask.png
# .100
# ../sardina_val/IMG_3483_r_200_mask.png
# .39
# ../sardina_val/IMG_3410_r_60_mask.png
# .221
# ../sardina_val/IMG_4363_r_100_mask.png
# .65
# ../sardina_val/IMG_3480_r_220_mask.png
# .152
# ../sardina_val/IMG_3486_r_140_mask.png
# .172
# ../sardina_val/IMG_3487_r_200_mask.png
# .191
# ../sardina_val/IMG_3520_r_220_mask.png
# .161
# ../sardina_val/IMG_3487_r_0_mask.png
# .183
# ../sardina_val/IMG_3520_r_80_mask.png
# .28
# ../sardina_val/IMG_3402_r_200_mask.png
# .134
# ../sardina_val/IMG_3485_r_180_mask.png
# .45
# ../sardina_val/IMG_3410_r_180_mask.png
# .205
# ../sardina_val/IMG_4350_r_120_mask.png
# .142
# ../sardina_val/IMG_3485_r_300_mask.png
# .131
# ../sardina_val/IMG_3485_r_100_mask.png
# .193
# ../sardina_val/IMG_3520_r_260_mask.png
# .122
# ../sardina_val/IMG_3484_r_280_mask.png
# .167
# ../sardina_val/IMG_3487_r_120_mask.png
# .79
# ../sardina_val/IMG_3482_r_140_mask.png
# .224
# ../sardina_val/IMG_4363_r_140_mask.png
# .47
# ../sardina_val/IMG_3410_r_220_mask.png
# .29
# ../sardina_val/IMG_3402_r_220_mask.png
# .111
# ../sardina_val/IMG_3484_r_40_mask.png
# .132
# ../sardina_val/IMG_3485_r_140_mask.png
# .86
# ../sardina_val/IMG_3482_r_260_mask.png
# .203
# ../sardina_val/IMG_4350_r_100_mask.png
# .98
# ../sardina_val/IMG_3483_r_160_mask.png
# .155
# ../sardina_val/IMG_3486_r_240_mask.png
# .226
# ../sardina_val/IMG_4363_r_200_mask.png
# .198
# ../sardina_val/IMG_4350_r_0_mask.png
# .225
# ../sardina_val/IMG_4363_r_180_mask.png
# .37
# ../sardina_val/IMG_3402_r_340_mask.png
# .195
# ../sardina_val/IMG_3520_r_320_mask.png
# .148
# ../sardina_val/IMG_3486_r_80_mask.png
# .73
# ../sardina_val/IMG_3482_r_20_mask.png
# .119
# ../sardina_val/IMG_3484_r_220_mask.png
# .32
# ../sardina_val/IMG_3402_r_280_mask.png
# .107
# ../sardina_val/IMG_3483_r_340_mask.png
# .201
# ../sardina_val/IMG_4350_r_60_mask.png
# .217
# ../sardina_val/IMG_4363_r_20_mask.png
# .88
# ../sardina_val/IMG_3482_r_320_mask.png
# .33
# ../sardina_val/IMG_3402_r_300_mask.png
# .189
# ../sardina_val/IMG_3520_r_180_mask.png
# .229
# ../sardina_val/IMG_4363_r_260_mask.png
# .75
# ../sardina_val/IMG_3482_r_60_mask.png
# .70
# ../sardina_val/IMG_3480_r_320_mask.png
# .186
# ../sardina_val/IMG_3520_r_120_mask.png
# .219
# ../sardina_val/IMG_4363_r_60_mask.png
# .207
# ../sardina_val/IMG_4350_r_160_mask.png
# .153
# ../sardina_val/IMG_3486_r_180_mask.png
# .204
# ../sardina_val/IMG_4350_r_140_mask.png
# .168
# ../sardina_val/IMG_3487_r_100_mask.png
# .108
# ../sardina_val/IMG_3484_r_0_mask.png
# .175
# ../sardina_val/IMG_3487_r_260_mask.png
# .138
# ../sardina_val/IMG_3485_r_240_mask.png
# .117
# ../sardina_val/IMG_3484_r_180_mask.png
# .68
# ../sardina_val/IMG_3480_r_280_mask.png
# .184
# ../sardina_val/IMG_3520_r_60_mask.png
# .154
# ../sardina_val/IMG_3486_r_200_mask.png
# .177
# ../sardina_val/IMG_3487_r_300_mask.png
# .174
# ../sardina_val/IMG_3487_r_240_mask.png
# .67
# ../sardina_val/IMG_3480_r_260_mask.png
# .212
# ../sardina_val/IMG_4350_r_260_mask.png
# .135
# ../sardina_val/IMG_3485_r_160_mask.png
# .49
# ../sardina_val/IMG_3410_r_240_mask.png
# .144
# ../sardina_val/IMG_3486_r_0_mask.png
# .64
# ../sardina_val/IMG_3480_r_160_mask.png
# .149
# ../sardina_val/IMG_3486_r_100_mask.png
# .46
# ../sardina_val/IMG_3410_r_160_mask.png
# .104
# ../sardina_val/IMG_3483_r_280_mask.png
# .232
# ../sardina_val/IMG_4363_r_320_mask.png
# .230
# ../sardina_val/IMG_4363_r_280_mask.png
# .55
# ../sardina_val/IMG_3480_r_20_mask.png
# .51
# ../sardina_val/IMG_3410_r_280_mask.png
# .101
# ../sardina_val/IMG_3483_r_220_mask.png
# .210
# ../sardina_val/IMG_4350_r_240_mask.png
# .50
# ../sardina_val/IMG_3410_r_300_mask.png
# .9
# ../sardina_val/IMG_3401_r_160_mask.png
# .162
# ../sardina_val/IMG_3486_r_340_mask.png
# .141
# ../sardina_val/IMG_3485_r_320_mask.png
# .62
# ../sardina_val/IMG_3480_r_180_mask.png
# .118
# ../sardina_val/IMG_3484_r_200_mask.png
# .48
# ../sardina_val/IMG_3410_r_260_mask.png
# .179
# ../sardina_val/IMG_3520_r_0_mask.png
# .14
# ../sardina_val/IMG_3401_r_260_mask.png
# .69
# ../sardina_val/IMG_3480_r_300_mask.png
# .160
# ../sardina_val/IMG_3486_r_320_mask.png
# .38
# ../sardina_val/IMG_3410_r_40_mask.png
# .113
# ../sardina_val/IMG_3484_r_100_mask.png
# .85
# ../sardina_val/IMG_3482_r_280_mask.png
# .11
# ../sardina_val/IMG_3401_r_220_mask.png
# .23
# ../sardina_val/IMG_3402_r_100_mask.png
# .170
# ../sardina_val/IMG_3487_r_180_mask.png
# .130
# ../sardina_val/IMG_3485_r_60_mask.png
# .169
# ../sardina_val/IMG_3487_r_160_mask.png
# .22
# ../sardina_val/IMG_3402_r_80_mask.png
# .157
# ../sardina_val/IMG_3486_r_260_mask.png
# .121
# ../sardina_val/IMG_3484_r_260_mask.png
# .133
# ../sardina_val/IMG_3485_r_120_mask.png
# .147
# ../sardina_val/IMG_3486_r_60_mask.png
# .84
# ../sardina_val/IMG_3482_r_240_mask.png
# .82
# ../sardina_val/IMG_3482_r_200_mask.png
# .196
# ../sardina_val/IMG_3520_r_300_mask.png
# .74
# ../sardina_val/IMG_3482_r_40_mask.png
# .208
# ../sardina_val/IMG_4350_r_220_mask.png
# .227
# ../sardina_val/IMG_4363_r_220_mask.png
# .209
# ../sardina_val/IMG_4350_r_200_mask.png
# .139
# ../sardina_val/IMG_3485_r_260_mask.png
# .60
# ../sardina_val/IMG_3480_r_140_mask.png
# .233
# ../sardina_val/IMG_4363_r_340_mask.png
# .126
# ../sardina_val/IMG_3485_r_20_mask.png
# .44
# ../sardina_val/IMG_3410_r_200_mask.png
# .110
# ../sardina_val/IMG_3484_r_60_mask.png
# .93
# ../sardina_val/IMG_3483_r_60_mask.png
# .5
# ../sardina_val/IMG_3401_r_100_mask.png
# .223
# ../sardina_val/IMG_4363_r_160_mask.png
# .164
# ../sardina_val/IMG_3487_r_40_mask.png
# .214
# ../sardina_val/IMG_4350_r_340_mask.png
# .56
# ../sardina_val/IMG_3480_r_40_mask.png
# .115
# ../sardina_val/IMG_3484_r_140_mask.png
# .124
# ../sardina_val/IMG_3484_r_300_mask.png
# .34
# ../sardina_val/IMG_3402_r_320_mask.png
# .222
# ../sardina_val/IMG_4363_r_120_mask.png
# .200
# ../sardina_val/IMG_4350_r_40_mask.png
# .102
# ../sardina_val/IMG_3483_r_240_mask.png
# .43
# ../sardina_val/IMG_3410_r_140_mask.png
# .136
# ../sardina_val/IMG_3485_r_220_mask.png
# .159
# ../sardina_val/IMG_3486_r_300_mask.png
# .187
# ../sardina_val/IMG_3520_r_140_mask.png
# .178
# ../sardina_val/IMG_3487_r_320_mask.png
# .218
# ../sardina_val/IMG_4363_r_40_mask.png
# .129
# ../sardina_val/IMG_3485_r_80_mask.png
# .26
# ../sardina_val/IMG_3402_r_160_mask.png
# .2
# ../sardina_val/IMG_3401_r_40_mask.png
# .158
# ../sardina_val/IMG_3486_r_280_mask.png
# .36
# ../sardina_val/IMG_3410_r_20_mask.png
# .146
# ../sardina_val/IMG_3486_r_40_mask.png
# .30
# ../sardina_val/IMG_3402_r_240_mask.png
# .194
# ../sardina_val/IMG_3520_r_280_mask.png
# .92
# ../sardina_val/IMG_3483_r_40_mask.png
# .52
# ../sardina_val/IMG_3410_r_320_mask.png
# .206
# ../sardina_val/IMG_4350_r_180_mask.png
# .228
# ../sardina_val/IMG_4363_r_240_mask.png
# .13
# ../sardina_val/IMG_3401_r_280_mask.png
# .94
# ../sardina_val/IMG_3483_r_100_mask.png
# .99
# ../sardina_val/IMG_3483_r_180_mask.png
# .83
# ../sardina_val/IMG_3482_r_220_mask.png
# .140
# ../sardina_val/IMG_3485_r_280_mask.png
# .66
# ../sardina_val/IMG_3480_r_240_mask.png
# .35
# ../sardina_val/IMG_3410_r_0_mask.png
# .216
# ../sardina_val/IMG_4363_r_0_mask.png
# .105
# ../sardina_val/IMG_3483_r_300_mask.png
# .165
# ../sardina_val/IMG_3487_r_60_mask.png
# .90
# ../sardina_val/IMG_3483_r_0_mask.png
# .63
# ../sardina_val/IMG_3480_r_200_mask.png
# .4
# ../sardina_val/IMG_3401_r_80_mask.png
# .41
# ../sardina_val/IMG_3410_r_100_mask.png
# .114
# ../sardina_val/IMG_3484_r_120_mask.png
# .59
# ../sardina_val/IMG_3480_r_100_mask.png
# .8
# ../sardina_val/IMG_3401_r_180_mask.png
# .77
# ../sardina_val/IMG_3482_r_100_mask.png
# .25
# ../sardina_val/IMG_3402_r_140_mask.png
# .20
# ../sardina_val/IMG_3402_r_40_mask.png
# .81
# ../sardina_val/IMG_3482_r_180_mask.png
# .163
# ../sardina_val/IMG_3487_r_20_mask.png
# .61
# ../sardina_val/IMG_3480_r_120_mask.png
# .128
# ../sardina_val/IMG_3485_r_40_mask.png
# .21
# ../sardina_val/IMG_3402_r_60_mask.png
# .145
# ../sardina_val/IMG_3486_r_20_mask.png
# .150
# ../sardina_val/IMG_3486_r_120_mask.png
# .231
# ../sardina_val/IMG_4363_r_300_mask.png
# .71
# ../sardina_val/IMG_3482_r_0_mask.png
# .87
# ../sardina_val/IMG_3482_r_300_mask.png
# .127
# ../sardina_val/IMG_3485_r_0_mask.png
# .103
# ../sardina_val/IMG_3483_r_260_mask.png
# .0
# ../sardina_val/IMG_3401_r_0_mask.png
# .6
# ../sardina_val/IMG_3401_r_120_mask.png
# .116
# ../sardina_val/IMG_3484_r_160_mask.png
# .181
# ../sardina_val/IMG_3520_r_20_mask.png
# .199
# ../sardina_val/IMG_4350_r_20_mask.png
# .17
# ../sardina_val/IMG_3402_r_0_mask.png
# .97
# ../sardina_val/IMG_3483_r_140_mask.png
# .176
# ../sardina_val/IMG_3487_r_280_mask.png
# .220
# ../sardina_val/IMG_4363_r_80_mask.png
# .76
# ../sardina_val/IMG_3482_r_80_mask.png
# .192
# ../sardina_val/IMG_3520_r_240_mask.png
# .106
# ../sardina_val/IMG_3483_r_320_mask.png
# .58
# ../sardina_val/IMG_3480_r_60_mask.png
# .10
# ../sardina_val/IMG_3401_r_200_mask.png
# .27
# ../sardina_val/IMG_3402_r_180_mask.png
# .54
# ../sardina_val/IMG_3480_r_0_mask.png
# .151
# ../sardina_val/IMG_3486_r_160_mask.png
# .16
# ../sardina_val/IMG_3401_r_320_mask.png
# .180
# ../sardina_val/IMG_3487_r_340_mask.png
# .125
# ../sardina_val/IMG_3484_r_340_mask.png
# .156
# ../sardina_val/IMG_3486_r_220_mask.png
# .185
# ../sardina_val/IMG_3520_r_100_mask.png
# .3
# ../sardina_val/IMG_3401_r_60_mask.png
# .188
# ../sardina_val/IMG_3520_r_160_mask.png
# .7
# ../sardina_val/IMG_3401_r_140_mask.png
# .182
# ../sardina_val/IMG_3520_r_40_mask.png
# .137
# ../sardina_val/IMG_3485_r_200_mask.png
# .109
# ../sardina_val/IMG_3484_r_20_mask.png
# .190
# ../sardina_val/IMG_3520_r_200_mask.png
# .24
# ../sardina_val/IMG_3402_r_120_mask.png
# .1
# ../sardina_val/IMG_3401_r_20_mask.png
# .213
# ../sardina_val/IMG_4350_r_300_mask.png
# .173
# ../sardina_val/IMG_3487_r_220_mask.png
# .96
# ../sardina_val/IMG_3483_r_120_mask.png
# .42
# ../sardina_val/IMG_3410_r_120_mask.png
# .211
# ../sardina_val/IMG_4350_r_280_mask.png
# .72
# ../sardina_val/IMG_3480_r_340_mask.png
# .120
# ../sardina_val/IMG_3484_r_240_mask.png
# .112
# ../sardina_val/IMG_3484_r_80_mask.png
# .202
# ../sardina_val/IMG_4350_r_80_mask.png
# .171
# ../sardina_val/IMG_3487_r_140_mask.png
# .40
# ../sardina_val/IMG_3410_r_80_mask.png
# .95
# ../sardina_val/IMG_3483_r_80_mask.png
# .
